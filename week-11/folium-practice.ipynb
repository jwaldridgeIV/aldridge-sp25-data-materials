# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /opt/anaconda3/lib/python3.12/site-packages (0.19.5)
# Requirement already satisfied: branca>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/anaconda3/lib/python3.12/site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /opt/anaconda3/lib/python3.12/site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->folium) (2024.12.14)

# %%
import folium
import pandas as pd

# %%
utah_df = pd.read_csv('1871-utah-postmaster-salaries.csv')
print(utah_df.sample(5))
utah_df.dtypes
# Out:
#            PO_Name      County State  PM_Salary   Latitude   Longitude
# 66           Logan       Cache    UT        290  41.734375 -111.834666
# 75            Mona        Juab    UT         18  39.816621 -111.850213
# 76          Monroe      Sevier    UT         12  38.631639 -112.121313
# 45          Hebron  Washington    UT         12  37.576642 -113.819415
# 5   Bingham Canyon   Salt Lake    UT         12  40.541613 -112.147997
# PO_Name       object
# County        object
# State         object
# PM_Salary      int64
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
utah_map_empty = folium.Map(location=[40, -111], zoom_start=6)
utah_map_empty
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25bf4d0184d6af86d59a2cc40dfc0a57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25bf4d0184d6af86d59a2cc40dfc0a57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25bf4d0184d6af86d59a2cc40dfc0a57 = L.map(
#                 &quot;map_25bf4d0184d6af86d59a2cc40dfc0a57&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_670569460dc561ce661803da08403f30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_670569460dc561ce661803da08403f30.addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def create_empty_map():
    return folium.Map(location=[40, -111], zoom_start=6)

utah_map = create_empty_map()
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7202eb4ceaa8f0bbcd79a47dc88af040 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7202eb4ceaa8f0bbcd79a47dc88af040&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7202eb4ceaa8f0bbcd79a47dc88af040 = L.map(
#                 &quot;map_7202eb4ceaa8f0bbcd79a47dc88af040&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b9016a55b27cfc68501cc70016f6104 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b9016a55b27cfc68501cc70016f6104.addTo(map_7202eb4ceaa8f0bbcd79a47dc88af040);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Check for columns with missing values
missing_values = utah_df.isna().sum()
print(missing_values)
# Out:
# PO_Name      0
# County       0
# State        0
# PM_Salary    0
# Latitude     4
# Longitude    4
# dtype: int64

# %%
# Filter out post offices that are missing a latitude value (ie. we don't have any location information about it)
utah_df_locations = utah_df[utah_df['Latitude'].notna()]
print(len(utah_df))
print(len(utah_df_locations))
# Out:
# 136
# 132

# %%
folium.Marker(location=[38.41, -112.339], popup="Adamsville Post Office").add_to(utah_map)
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7202eb4ceaa8f0bbcd79a47dc88af040 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7202eb4ceaa8f0bbcd79a47dc88af040&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7202eb4ceaa8f0bbcd79a47dc88af040 = L.map(
#                 &quot;map_7202eb4ceaa8f0bbcd79a47dc88af040&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b9016a55b27cfc68501cc70016f6104 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b9016a55b27cfc68501cc70016f6104.addTo(map_7202eb4ceaa8f0bbcd79a47dc88af040);
#
#
#             tile_layer_0b9016a55b27cfc68501cc70016f6104.addTo(map_7202eb4ceaa8f0bbcd79a47dc88af040);
#
#
#             var marker_7780edb25e5d2619371fc7e7838b9165 = L.marker(
#                 [38.41, -112.339],
#                 {
# }
#             ).addTo(map_7202eb4ceaa8f0bbcd79a47dc88af040);
#
#
#         var popup_4ded8bebed36d4746618436d3b8be926 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1befffa7bf4421c738b7049594a1c85 = $(`&lt;div id=&quot;html_f1befffa7bf4421c738b7049594a1c85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville Post Office&lt;/div&gt;`)[0];
#                 popup_4ded8bebed36d4746618436d3b8be926.setContent(html_f1befffa7bf4421c738b7049594a1c85);
#
#
#
#         marker_7780edb25e5d2619371fc7e7838b9165.bindPopup(popup_4ded8bebed36d4746618436d3b8be926)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Melanie Walsh function we will adadpt to our dataset:
# def create_map_markers(row, map_name):
#    folium.Marker(location=[row['lat'], row['lon']], popup=row['place']).add_to(map_name)

def create_map_markers(row, map_name):
    folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row['PO_Name']).add_to(map_name)

# %%
#create a base empty map
utah_map = create_empty_map()

#generate a random row of data
sample_row = utah_df_locations.sample(1)

#use our function on the random row
create_map_markers(sample_row, utah_map)

#display the map
utah_map
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/folium/utilities.py:101: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(coord)
# /opt/anaconda3/lib/python3.12/site-packages/folium/utilities.py:107: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   if math.isnan(float(coord)):
# /opt/anaconda3/lib/python3.12/site-packages/folium/utilities.py:109: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return [float(x) for x in coords]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae82ca7f6e64c1c4dc48917a2958e0e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae82ca7f6e64c1c4dc48917a2958e0e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae82ca7f6e64c1c4dc48917a2958e0e1 = L.map(
#                 &quot;map_ae82ca7f6e64c1c4dc48917a2958e0e1&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01caf098d47554fba72b6644231df854 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_01caf098d47554fba72b6644231df854.addTo(map_ae82ca7f6e64c1c4dc48917a2958e0e1);
#
#
#             var marker_738b802b58abba8534d78a0e1e79f44f = L.marker(
#                 [39.4869056, -111.6351961],
#                 {
# }
#             ).addTo(map_ae82ca7f6e64c1c4dc48917a2958e0e1);
#
#
#         var popup_c3b0b444b52b86681f67f1d5c3222f23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8402ce5dca5993853b9fc4836d877c4b = $(`&lt;div id=&quot;html_8402ce5dca5993853b9fc4836d877c4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;125    Wales Name: PO_Name, dtype: object&lt;/div&gt;`)[0];
#                 popup_c3b0b444b52b86681f67f1d5c3222f23.setContent(html_8402ce5dca5993853b9fc4836d877c4b);
#
#
#
#         marker_738b802b58abba8534d78a0e1e79f44f.bindPopup(popup_c3b0b444b52b86681f67f1d5c3222f23)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Method 1: Using a for loop to iterate through our dataframe and add markers sequentially
# initialize an empty map
utah_map = create_empty_map()

# iterrows() allows you to loop through a dataframe row by row and return the index position + the row
for index, row in utah_df_locations.iterrows():
    print(f"Name of post office:", row[0])

#now let's iterate through and call our function for each row
for index, row in utah_df_locations.iterrows():
    create_map_markers(row, utah_map)

utah_map
# Out:
# Name of post office: Adamsville
# Name of post office: Alma
# Name of post office: Alpine City
# Name of post office: American Fork
# Name of post office: Bellevue
# Name of post office: Bingham Canyon
# Name of post office: Brigham City
# Name of post office: Bullion
# Name of post office: Cedar City
# Name of post office: Cedar Valley
# Name of post office: Centerville
# Name of post office: Central City
# Name of post office: Chicken Creek
# Name of post office: Clarkston
# Name of post office: Clifton
# Name of post office: Clover Valley
# Name of post office: Coalville
# Name of post office: Corinne
# Name of post office: Cove Creek
# Name of post office: Croydon
# Name of post office: Deseret
# Name of post office: Diamond
# Name of post office: Draper
# Name of post office: Duncans Retreat
# Name of post office: Echo City
# Name of post office: Eden
# Name of post office: Emmaville
# Name of post office: Ephraim
# Name of post office: Eureka
# Name of post office: Fair View
# Name of post office: Fairfield
# Name of post office: Farmington
# Name of post office: Fillmore City
# Name of post office: Forest City
# Name of post office: Fort Hamblin
# Name of post office: Fountain Green
# Name of post office: Franklin
# Name of post office: Goshen
# Name of post office: Grafton
# Name of post office: Grantsville
# Name of post office: Gunnison
# Name of post office: Harrisburg
# Name of post office: Harrisville
# Name of post office: Heber
# Name of post office: Hebron
# Name of post office: Herriman
# Name of post office: Holden
# Name of post office: Hooper
# Name of post office: Huntsville
# Name of post office: Hyde Park
# Name of post office: Hyrum
# Name of post office: Iron City
# Name of post office: Johnson
# Name of post office: Kamas
# Name of post office: Kanab
# Name of post office: Kanarraville
# Name of post office: Kanosh
# Name of post office: Kaysville
# Name of post office: Kelton
# Name of post office: Lake Point
# Name of post office: Leeds
# Name of post office: Lehi City
# Name of post office: Levan
# Name of post office: Liberty
# Name of post office: Logan
# Name of post office: Lynne
# Name of post office: Manti
# Name of post office: Meadow
# Name of post office: Mendon
# Name of post office: Midway
# Name of post office: Mill Creek
# Name of post office: Millville
# Name of post office: Minersville
# Name of post office: Mona
# Name of post office: Monroe
# Name of post office: Morgan
# Name of post office: Moroni
# Name of post office: New Harmony
# Name of post office: Newton
# Name of post office: North Ogden
# Name of post office: Ogden City
# Name of post office: Ophir
# Name of post office: Paradise
# Name of post office: Paragonah
# Name of post office: Parowan
# Name of post office: Payson
# Name of post office: Peoa
# Name of post office: Petersburgh
# Name of post office: Peterson
# Name of post office: Pine Valley
# Name of post office: Pinto
# Name of post office: Plain City
# Name of post office: Pleasant Grove
# Name of post office: Portage
# Name of post office: Providence
# Name of post office: Provo City
# Name of post office: Richfield
# Name of post office: Richmond
# Name of post office: Riverdale
# Name of post office: Rockville
# Name of post office: Saint George
# Name of post office: Salina
# Name of post office: Salt Creek
# Name of post office: Salt Lake City
# Name of post office: Santaquin
# Name of post office: Scipio
# Name of post office: Silver City
# Name of post office: Slatersville
# Name of post office: Smithfield
# Name of post office: South Cottonwood
# Name of post office: Spanish Fork
# Name of post office: Spring City
# Name of post office: Springdale
# Name of post office: Springville
# Name of post office: Stockton
# Name of post office: Stoker
# Name of post office: Summit
# Name of post office: Tokersville
# Name of post office: Tooele
# Name of post office: Uintah
# Name of post office: Union
# Name of post office: Virgin City
# Name of post office: Wales
# Name of post office: Wallsburg
# Name of post office: Wanship
# Name of post office: Wasatch
# Name of post office: Washington
# Name of post office: Wellsville
# Name of post office: West Jordan
# Name of post office: Willard
# Name of post office: Winsor
# Name of post office: Woods Cross
# /var/folders/35/7877ljzn6nj5tdww9cfrpbz40000gn/T/ipykernel_98618/2508161898.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Name of post office:", row[0])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af0d5754806ed9e2d16442139d505ece {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af0d5754806ed9e2d16442139d505ece&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af0d5754806ed9e2d16442139d505ece = L.map(
#                 &quot;map_af0d5754806ed9e2d16442139d505ece&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f53d932903df778e3254a4c12a0c40c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f53d932903df778e3254a4c12a0c40c.addTo(map_af0d5754806ed9e2d16442139d505ece);
#
#
#             var marker_592224f916cca3725f6e151e4ddd1e55 = L.marker(
#                 [38.2583031, -112.7938352],
#                 {
# }
#             ).addTo(map_af0d5754806ed9e2d16442139d505ece);
#
#
#         var popup_9e6a0c280a1f15cf2ffa69e292524694 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84581968175ae5eaf77a006b133e2b1e = $(`&lt;div id=&quot;html_84581968175ae5eaf77a006b133e2b1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_9e6a0c280a1f15cf2ffa69e292524694.setContent(html_84581968175ae5eaf77a006b133e2b1e);
#
#
#
#         marker_592224f916cca3725f6e151e4ddd1e55.bindPopup(popup_9e6a0c280a1f15cf2ffa69e292524694)
#         ;
#
#
#
#
#             var marker_86bb6c65c98d5eddbe3fda300ba54d65 = L.marker(
#                 [41.2488333, -112.0782749],
#                 {
# }
#             ).addTo(map_af0d5754806ed9e2d16442139d505ece);
#
#
#         var popup_4324ab7dda961c9d067a4deb47b79ffd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8832dcbf9832c0f5434c7800271d3b7b = $(`&lt;div id=&quot;html_8832dcbf9832c0f5434c7800271d3b7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_4324ab7dda961c9d067a4deb47b79ffd.setContent(html_8832dcbf9832c0f5434c7800271d3b7b);
#
#
#
#         marker_86bb6c65c98d5eddbe3fda300ba54d65.bindPopup(popup_4324ab7dda961c9d067a4deb47b79ffd)
#         ;
#
#
#
#
#             var marker_c0bd8bb02bfcb6ca178a9eb3acf8be62 = L.marker(
#                 [40.4532834, -111.7779865],
#                 {
# }
#             ).addTo(map_af0d5754806ed9e2d16442139d505ece);
#
#
#         var popup_fffbb4b349153042863838df96c30261 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e996fa85f7078a26012aac8f64469d6 = $(`&lt;div id=&quot;html_1e996fa85f7078a26012aac8f64469d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_fffbb4b349153042863838df96c30261.setContent(html_1e996fa85f7078a26012aac8f64469d6);
#
#
#
#         marker_c0bd8bb02bfcb6ca178a9eb3acf8be62.bindPopup(popup_fffbb4b349153042863838df96c30261)
#         ;
#
#
#
#
#             var marker_3f06eba5b85460b2cbe059876a6a104a = L.marker(
#                 [40.3752288, -111.7963201],
#                 {
# }
#             ).addTo(map_af0d5754806ed9e2d16442139d505ece);
#
#
#         var popup_d812195db491397883d0be01e2a56b82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfe5f89a9bfc12774c9e9dd791d71016 = $(`&lt;div id=&quot;html_cfe5f89a9bfc12774c9e9dd791d71016&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American Fork&lt;/div&gt;`)[0];
#                 popup_d812195db491397883d0be01e2a56b82.setContent(html_cfe5f89a9bfc12774c9e9dd791d71016);
#
#
#
#         marker_3f06eba5b85460b2cbe059876a6a104a.bindPopup(popup_d812195db491397883d0be01e2a56b82)
#         ;
#
#
#
#
#             var marker_5fdadaab00f2576de6096ef3b05812ea = L.marker(
#                 [37.3408149, -113.2741158],
#                 {
# }
#             ).addTo(map_af0d5754806ed9e2d16442139d505ece);
#
#
#         var popup_00eb9b3e838a2dcc6489d3511b49558f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_284126a0644f3df3e181c5de0fc23fdf = $(`&lt;div id=&quot;html_284126a0644f3df3e181c5de0fc23fdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bellevue&lt;/div&gt;`)[0];
#                 popup_00eb9b3e838a2dcc6489d3511b49558f.setContent(html_284126a0644f3df3e181c5de0fc23fdf);
#
#
#
#         marker_5fdadaab00f2576de6096ef3b05812ea.bindPopup(popup_00eb9b3e838a2dcc6489d3511b49558f)
#         ;
#
#
#
#
#             var marker_08b4ea680554cb58270af48aeef727d2 = L.marker(
#                 [40.5416128, -112.1479974],
#                 {
# }

# %%
# Method 2: Using .apply() to add markers with our function for all rows
# initialize an empty map
utah_map = utah_map_empty

# Now apply this function to each row in our filtered DataFrame
# For each row, we'll pass:
# 1. The row itself (handled automatically by .apply())
# 2. Our map object (we need to specify this explicitly)
# 3. The "axis" value for .apply() to indicate we want to process row by row
# .apply() allows you to apply a function to each row in the dataframe
utah_df_locations.apply(
    create_map_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25bf4d0184d6af86d59a2cc40dfc0a57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25bf4d0184d6af86d59a2cc40dfc0a57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25bf4d0184d6af86d59a2cc40dfc0a57 = L.map(
#                 &quot;map_25bf4d0184d6af86d59a2cc40dfc0a57&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_670569460dc561ce661803da08403f30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_670569460dc561ce661803da08403f30.addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#             tile_layer_670569460dc561ce661803da08403f30.addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#             var marker_04f311b3523cd0fcb8d34e71033be7a3 = L.marker(
#                 [38.2583031, -112.7938352],
#                 {
# }
#             ).addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#         var popup_56a4e5877e54afa4ab7e7467444fde11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c8cd2adefcf2ab543e97dc560c16d32 = $(`&lt;div id=&quot;html_6c8cd2adefcf2ab543e97dc560c16d32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_56a4e5877e54afa4ab7e7467444fde11.setContent(html_6c8cd2adefcf2ab543e97dc560c16d32);
#
#
#
#         marker_04f311b3523cd0fcb8d34e71033be7a3.bindPopup(popup_56a4e5877e54afa4ab7e7467444fde11)
#         ;
#
#
#
#
#             var marker_a246c774f81dda742b0036c1b18b057e = L.marker(
#                 [41.2488333, -112.0782749],
#                 {
# }
#             ).addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#         var popup_52a31c746334fd65cf2849b1abe6fabd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3ced0708dd0f1e4fa56002e7bdc7e11 = $(`&lt;div id=&quot;html_d3ced0708dd0f1e4fa56002e7bdc7e11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_52a31c746334fd65cf2849b1abe6fabd.setContent(html_d3ced0708dd0f1e4fa56002e7bdc7e11);
#
#
#
#         marker_a246c774f81dda742b0036c1b18b057e.bindPopup(popup_52a31c746334fd65cf2849b1abe6fabd)
#         ;
#
#
#
#
#             var marker_e0fc7ad7e4479a75a6323fce9dd24167 = L.marker(
#                 [40.4532834, -111.7779865],
#                 {
# }
#             ).addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#         var popup_4ab9a18b3fa9bd52eb5b0153f234762e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc00d88544aec4546af38745f6628639 = $(`&lt;div id=&quot;html_bc00d88544aec4546af38745f6628639&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_4ab9a18b3fa9bd52eb5b0153f234762e.setContent(html_bc00d88544aec4546af38745f6628639);
#
#
#
#         marker_e0fc7ad7e4479a75a6323fce9dd24167.bindPopup(popup_4ab9a18b3fa9bd52eb5b0153f234762e)
#         ;
#
#
#
#
#             var marker_6175acd215a26a66709837a793c12ec1 = L.marker(
#                 [40.3752288, -111.7963201],
#                 {
# }
#             ).addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#         var popup_18b5f7205d7fabefd22df698d9f9cd52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7be185b93f2b75bae43a23c097423e16 = $(`&lt;div id=&quot;html_7be185b93f2b75bae43a23c097423e16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American Fork&lt;/div&gt;`)[0];
#                 popup_18b5f7205d7fabefd22df698d9f9cd52.setContent(html_7be185b93f2b75bae43a23c097423e16);
#
#
#
#         marker_6175acd215a26a66709837a793c12ec1.bindPopup(popup_18b5f7205d7fabefd22df698d9f9cd52)
#         ;
#
#
#
#
#             var marker_7d79191b83df9a76852ee0d42ac4ba1a = L.marker(
#                 [37.3408149, -113.2741158],
#                 {
# }
#             ).addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#         var popup_d29f5403872fcc815a9a5ab87b2c7b09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d140514049aa18758075616e0769a38 = $(`&lt;div id=&quot;html_2d140514049aa18758075616e0769a38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bellevue&lt;/div&gt;`)[0];
#                 popup_d29f5403872fcc815a9a5ab87b2c7b09.setContent(html_2d140514049aa18758075616e0769a38);
#
#
#
#         marker_7d79191b83df9a76852ee0d42ac4ba1a.bindPopup(popup_d29f5403872fcc815a9a5ab87b2c7b09)
#         ;
#
#
#
#
#             var

# %%
# alter map appearance
def create_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=5,
                       color='red',
                       fill=True,
                       fill_color='green',
                       fill_opacity=0.5,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a281e365a0dfa2b0db7a0f2bbafa03a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a281e365a0dfa2b0db7a0f2bbafa03a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a281e365a0dfa2b0db7a0f2bbafa03a = L.map(
#                 &quot;map_2a281e365a0dfa2b0db7a0f2bbafa03a&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8114df676bf4d3c9103b28bd2fdf8a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c8114df676bf4d3c9103b28bd2fdf8a6.addTo(map_2a281e365a0dfa2b0db7a0f2bbafa03a);
#
#
#             var circle_marker_45d523a43ff6d7a344fc7ccb3d81af17 = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2a281e365a0dfa2b0db7a0f2bbafa03a);
#
#
#         var popup_7a51ef24b0fe340dc593bdbfa6266a29 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_f8be4f9ee1f8795f7509fd6b711de05c = $(`&lt;div id=&quot;html_f8be4f9ee1f8795f7509fd6b711de05c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_7a51ef24b0fe340dc593bdbfa6266a29.setContent(html_f8be4f9ee1f8795f7509fd6b711de05c);
#
#
#
#         circle_marker_45d523a43ff6d7a344fc7ccb3d81af17.bindPopup(popup_7a51ef24b0fe340dc593bdbfa6266a29)
#         ;
#
#
#
#
#             circle_marker_45d523a43ff6d7a344fc7ccb3d81af17.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_f59e6582ddbe4955be5548985516e1eb = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2a281e365a0dfa2b0db7a0f2bbafa03a);
#
#
#         var popup_b32d44d60082798f03e4ee094ef120b8 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_ed42a2c903122488357603d33a9d6693 = $(`&lt;div id=&quot;html_ed42a2c903122488357603d33a9d6693&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_b32d44d60082798f03e4ee094ef120b8.setContent(html_ed42a2c903122488357603d33a9d6693);
#
#
#
#         circle_marker_f59e6582ddbe4955be5548985516e1eb.bindPopup(popup_b32d44d60082798f03e4ee094ef120b8)
#         ;
#
#
#
#
#             circle_marker_f59e6582ddbe4955be5548985516e1eb.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_45f7429d3a825660eb3b8abea37a1e7d = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2a281e365a0dfa2b0db7a0f2bbafa03a);
#
#
#         var popup_66d792a0dca45621c54a277db89f284e = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_a30ed19fdad0f798f9ec9b4622d72619 = $(`&lt;div id=&quot;html_a30ed19fdad0f798f9ec9b4622d72619&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_66d792a0dca45621c54a277db89f284e.setContent(html_a30ed19f

# %%
# make new function to create circle markers sized by postmaster salary - this time adjusting the radius size in pixels to make it more legible
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['PM_Salary']/100,
                       fill=True,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_133ee8c9d1b188d25b56c3eb7c5cbf55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_133ee8c9d1b188d25b56c3eb7c5cbf55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_133ee8c9d1b188d25b56c3eb7c5cbf55 = L.map(
#                 &quot;map_133ee8c9d1b188d25b56c3eb7c5cbf55&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_194f99fe803aa73c8a383afea9f6d0d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_194f99fe803aa73c8a383afea9f6d0d4.addTo(map_133ee8c9d1b188d25b56c3eb7c5cbf55);
#
#
#             var circle_marker_8d97c3f9450db43e646a51fe7b9b383e = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_133ee8c9d1b188d25b56c3eb7c5cbf55);
#
#
#         var popup_1a86283d0b3e65dc7e65ca85337d58c6 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_2b0e26e2a2f7ee1dc5105367448aebfc = $(`&lt;div id=&quot;html_2b0e26e2a2f7ee1dc5105367448aebfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_1a86283d0b3e65dc7e65ca85337d58c6.setContent(html_2b0e26e2a2f7ee1dc5105367448aebfc);
#
#
#
#         circle_marker_8d97c3f9450db43e646a51fe7b9b383e.bindPopup(popup_1a86283d0b3e65dc7e65ca85337d58c6)
#         ;
#
#
#
#
#             circle_marker_8d97c3f9450db43e646a51fe7b9b383e.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_8ff0aaf87ed8b22ce75452d415e2abd7 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.12, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_133ee8c9d1b188d25b56c3eb7c5cbf55);
#
#
#         var popup_60c8798a40c254260caa8962203477c7 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_aa6f761efd0945bc6aead7e474a6b33d = $(`&lt;div id=&quot;html_aa6f761efd0945bc6aead7e474a6b33d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_60c8798a40c254260caa8962203477c7.setContent(html_aa6f761efd0945bc6aead7e474a6b33d);
#
#
#
#         circle_marker_8ff0aaf87ed8b22ce75452d415e2abd7.bindPopup(popup_60c8798a40c254260caa8962203477c7)
#         ;
#
#
#
#
#             circle_marker_8ff0aaf87ed8b22ce75452d415e2abd7.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_1bc85b0af4a07dea5bd2cec200bf67a1 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.27, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_133ee8c9d1b188d25b56c3eb7c5cbf55);
#
#
#         var popup_d538c45bf578b3b4c9ac1769ca75426b = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_68ffd0915940c961c37314ca17aed8f0 = $(`&lt;div id=&quot;html_68ffd0915940c961c37314ca17aed8f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_d538c45bf578b3b4c9ac1769ca75426

# %%
utah_df_locations.describe()
# Out:
#          PM_Salary    Latitude   Longitude
# count   132.000000  132.000000  132.000000
# mean    101.098485   39.907743 -112.161190
# std     344.225580    1.505091    0.593117
# min       4.000000   37.006375 -113.819415
# 25%      12.000000   38.874099 -112.379230
# 50%      22.000000   40.380926 -111.973830
# 75%      70.000000   41.080917 -111.819912
# max    3600.000000   42.187500 -111.281850

# %%
def add_salary_buckets(salary):
    # Create a new column for the salary bucket
    if salary < 50:
        bucket = 'Low Salary'
    elif salary >= 50 and salary < 250:
        bucket = 'Medium Salary'
    elif salary >= 250 and salary < 1000:
        bucket = 'High Salary'
    else:
        bucket = 'Very High Salary'
    return bucket

# %%
#test out the function
add_salary_buckets(2000)
# Out:
# 'Very High Salary'

# %%
utah_df_locations['Salary_Bucket'] = utah_df_locations['PM_Salary'].apply(add_salary_buckets)
utah_df_locations.head()
# Out:
# /var/folders/35/7877ljzn6nj5tdww9cfrpbz40000gn/T/ipykernel_98618/2959544325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   utah_df_locations['Salary_Bucket'] = utah_df_locations['PM_Salary'].apply(add_salary_buckets)
#          PO_Name      County State  PM_Salary   Latitude   Longitude  \
# 0     Adamsville      Beaver    UT         10  38.258303 -112.793835
# 1           Alma       Weber    UT         12  41.248833 -112.078275
# 2    Alpine City        Utah    UT         27  40.453283 -111.777986
# 3  American Fork        Utah    UT        130  40.375229 -111.796320
# 4       Bellevue  Washington    UT         20  37.340815 -113.274116
#
#    Salary_Bucket
# 0     Low Salary
# 1     Low Salary
# 2     Low Salary
# 3  Medium Salary
# 4     Low Salary

# %%
# create a function to add marker sizes based on the salary bucket
def add_marker_sizes(category):
    if category == 'Low Salary':
        return 4
    elif category == 'Medium Salary':
        return 8
    elif category == 'High Salary':
        return 12
    else:
        return 16

#test out the function
add_marker_sizes('High Salary')
# Out:
# 12

# %%
utah_df_locations['Marker_Size'] = utah_df_locations['Salary_Bucket'].apply(add_marker_sizes)
utah_df_locations.head(10)
# Out:
# /var/folders/35/7877ljzn6nj5tdww9cfrpbz40000gn/T/ipykernel_98618/3689819186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   utah_df_locations['Marker_Size'] = utah_df_locations['Salary_Bucket'].apply(add_marker_sizes)
#            PO_Name      County State  PM_Salary   Latitude   Longitude  \
# 0       Adamsville      Beaver    UT         10  38.258303 -112.793835
# 1             Alma       Weber    UT         12  41.248833 -112.078275
# 2      Alpine City        Utah    UT         27  40.453283 -111.777986
# 3    American Fork        Utah    UT        130  40.375229 -111.796320
# 4         Bellevue  Washington    UT         20  37.340815 -113.274116
# 5   Bingham Canyon   Salt Lake    UT         12  40.541613 -112.147997
# 7     Brigham City   Box Elder    UT        400  41.510213 -112.015501
# 8          Bullion       Piute    UT         12  38.410000 -112.339000
# 9       Cedar City        Iron    UT        200  37.676644 -113.057171
# 10    Cedar Valley        Utah    UT         13  40.327171 -112.104385
#
#     Salary_Bucket  Marker_Size
# 0      Low Salary            4
# 1      Low Salary            4
# 2      Low Salary            4
# 3   Medium Salary            8
# 4      Low Salary            4
# 5      Low Salary            4
# 7     High Salary           12
# 8      Low Salary            4
# 9   Medium Salary            8
# 10     Low Salary            4

# %%
# make new function to create circle markers sized by salary category
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['Marker_Size'],
                       fill=True,
                       opacity=0.6,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4213c3d6df497a5b3d714c08bd01d6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4213c3d6df497a5b3d714c08bd01d6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4213c3d6df497a5b3d714c08bd01d6a = L.map(
#                 &quot;map_e4213c3d6df497a5b3d714c08bd01d6a&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec2948bd2e73c956ef09cd44a570bba0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec2948bd2e73c956ef09cd44a570bba0.addTo(map_e4213c3d6df497a5b3d714c08bd01d6a);
#
#
#             var circle_marker_551a6df355ad85718103f697c9753393 = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e4213c3d6df497a5b3d714c08bd01d6a);
#
#
#         var popup_a52d099b610d4ace2224c0d06ca9ffa8 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_397078b5de22d8d00cd97ba3ef808b7c = $(`&lt;div id=&quot;html_397078b5de22d8d00cd97ba3ef808b7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_a52d099b610d4ace2224c0d06ca9ffa8.setContent(html_397078b5de22d8d00cd97ba3ef808b7c);
#
#
#
#         circle_marker_551a6df355ad85718103f697c9753393.bindPopup(popup_a52d099b610d4ace2224c0d06ca9ffa8)
#         ;
#
#
#
#
#             circle_marker_551a6df355ad85718103f697c9753393.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_55c299341fd594ed3f69c91bd87853e5 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e4213c3d6df497a5b3d714c08bd01d6a);
#
#
#         var popup_050f332371f2f369343e01356855c6ff = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_41d4b0dd837cfc3567b5ce3aed1d283d = $(`&lt;div id=&quot;html_41d4b0dd837cfc3567b5ce3aed1d283d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_050f332371f2f369343e01356855c6ff.setContent(html_41d4b0dd837cfc3567b5ce3aed1d283d);
#
#
#
#         circle_marker_55c299341fd594ed3f69c91bd87853e5.bindPopup(popup_050f332371f2f369343e01356855c6ff)
#         ;
#
#
#
#
#             circle_marker_55c299341fd594ed3f69c91bd87853e5.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_67268f9ecd17596957f2ef4496cf85fe = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e4213c3d6df497a5b3d714c08bd01d6a);
#
#
#         var popup_a0cb06b98a91f9b380763a8740d10a14 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_71850f5affc64e13ddaa4605fca46d4f = $(`&lt;div id=&quot;html_71850f5affc64e13ddaa4605fca46d4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_a0cb06b98a91f9b380763a8740d10a14.setCon

# %%
utah_1877_df = pd.read_csv('1877-official-register.csv')
utah_1877_df.dtypes
# Out:
# Name           object
# State          object
# Department     object
# Type           object
# People          int64
# Latitude      float64
# Longitude     float64
# dtype: object

# %%
# Melanie Walsh function we will adadpt to our dataset:
# def create_map_markers(row, map_name):
#    folium.Marker(location=[row['lat'], row['lon']], popup=row['place']).add_to(map_name)

def create_map_markers(row, map_name):
    folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row['Name']).add_to(map_name)

# %%
# Method 2: Using .apply() to add markers with our function for all rows
# initialize an empty map
gov_map = utah_map_empty


gov_df = utah_1877_df[utah_1877_df['Latitude'].notna()]
# Now apply this function to each row in our filtered DataFrame
# For each row, we'll pass:
# 1. The row itself (handled automatically by .apply())
# 2. Our map object (we need to specify this explicitly)
# 3. The "axis" value for .apply() to indicate we want to process row by row
# .apply() allows you to apply a function to each row in the dataframe
gov_df.apply(
    create_map_markers, # The function to apply
    map_name=gov_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

gov_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25bf4d0184d6af86d59a2cc40dfc0a57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25bf4d0184d6af86d59a2cc40dfc0a57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25bf4d0184d6af86d59a2cc40dfc0a57 = L.map(
#                 &quot;map_25bf4d0184d6af86d59a2cc40dfc0a57&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_670569460dc561ce661803da08403f30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_670569460dc561ce661803da08403f30.addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#             tile_layer_670569460dc561ce661803da08403f30.addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#             var marker_04f311b3523cd0fcb8d34e71033be7a3 = L.marker(
#                 [38.2583031, -112.7938352],
#                 {
# }
#             ).addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#         var popup_56a4e5877e54afa4ab7e7467444fde11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c8cd2adefcf2ab543e97dc560c16d32 = $(`&lt;div id=&quot;html_6c8cd2adefcf2ab543e97dc560c16d32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_56a4e5877e54afa4ab7e7467444fde11.setContent(html_6c8cd2adefcf2ab543e97dc560c16d32);
#
#
#
#         marker_04f311b3523cd0fcb8d34e71033be7a3.bindPopup(popup_56a4e5877e54afa4ab7e7467444fde11)
#         ;
#
#
#
#
#             var marker_a246c774f81dda742b0036c1b18b057e = L.marker(
#                 [41.2488333, -112.0782749],
#                 {
# }
#             ).addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#         var popup_52a31c746334fd65cf2849b1abe6fabd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3ced0708dd0f1e4fa56002e7bdc7e11 = $(`&lt;div id=&quot;html_d3ced0708dd0f1e4fa56002e7bdc7e11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_52a31c746334fd65cf2849b1abe6fabd.setContent(html_d3ced0708dd0f1e4fa56002e7bdc7e11);
#
#
#
#         marker_a246c774f81dda742b0036c1b18b057e.bindPopup(popup_52a31c746334fd65cf2849b1abe6fabd)
#         ;
#
#
#
#
#             var marker_e0fc7ad7e4479a75a6323fce9dd24167 = L.marker(
#                 [40.4532834, -111.7779865],
#                 {
# }
#             ).addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#         var popup_4ab9a18b3fa9bd52eb5b0153f234762e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc00d88544aec4546af38745f6628639 = $(`&lt;div id=&quot;html_bc00d88544aec4546af38745f6628639&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_4ab9a18b3fa9bd52eb5b0153f234762e.setContent(html_bc00d88544aec4546af38745f6628639);
#
#
#
#         marker_e0fc7ad7e4479a75a6323fce9dd24167.bindPopup(popup_4ab9a18b3fa9bd52eb5b0153f234762e)
#         ;
#
#
#
#
#             var marker_6175acd215a26a66709837a793c12ec1 = L.marker(
#                 [40.3752288, -111.7963201],
#                 {
# }
#             ).addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#         var popup_18b5f7205d7fabefd22df698d9f9cd52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7be185b93f2b75bae43a23c097423e16 = $(`&lt;div id=&quot;html_7be185b93f2b75bae43a23c097423e16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American Fork&lt;/div&gt;`)[0];
#                 popup_18b5f7205d7fabefd22df698d9f9cd52.setContent(html_7be185b93f2b75bae43a23c097423e16);
#
#
#
#         marker_6175acd215a26a66709837a793c12ec1.bindPopup(popup_18b5f7205d7fabefd22df698d9f9cd52)
#         ;
#
#
#
#
#             var marker_7d79191b83df9a76852ee0d42ac4ba1a = L.marker(
#                 [37.3408149, -113.2741158],
#                 {
# }
#             ).addTo(map_25bf4d0184d6af86d59a2cc40dfc0a57);
#
#
#         var popup_d29f5403872fcc815a9a5ab87b2c7b09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d140514049aa18758075616e0769a38 = $(`&lt;div id=&quot;html_2d140514049aa18758075616e0769a38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bellevue&lt;/div&gt;`)[0];
#                 popup_d29f5403872fcc815a9a5ab87b2c7b09.setContent(html_2d140514049aa18758075616e0769a38);
#
#
#
#         marker_7d79191b83df9a76852ee0d42ac4ba1a.bindPopup(popup_d29f5403872fcc815a9a5ab87b2c7b09)
#         ;
#
#
#
#
#             var
